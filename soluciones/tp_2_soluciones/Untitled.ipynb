# %% [markdown]
# # Trabajo práctico 0: Conjuntos, Relaciones y Funciones

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Parte B: Relaciones y Funciones

# %% [markdown]
# ### Ejercicio 2

# %%
# a)
fig,ax = plt.subplots(figsize = (8,8))
ax.set_ylim((-2,5))
ax.set_xlim((0,6))
ax.axhline(0,color = 'k',lw = 0.5)
ax.axvline(2,color = 'k',ymax = 6/7)
ax.axvline(5,color = 'k',ymax = 6/7)
ax.axhline(4,ls = '--',color = 'k',xmin = 2/6,xmax = 5/6)
ax.fill_between(x = [2,5],y1 = -2,y2 = 4,alpha = 0.2)
ax.grid()
ax.set_ylabel('y',fontsize = 16)
ax.set_xlabel('x',fontsize = 16)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig('2a.svg')

# %%
# b)
fig,ax = plt.subplots(figsize = (8,8))
ax.set_ylim((-2,6))
ax.set_xlim((0,6))
ax.axhline(0,color = 'k',lw = 0.5)
ax.axvline(4,color = 'k',ymax = 7/8)
ax.axhline(5,ls = '--',color = 'k',xmin = 4/6,xmax = 1)
ax.fill_between(x = [4,6],y1 = -2,y2 = 5,alpha = 0.2)
ax.grid()
ax.set_ylabel('y',fontsize = 16)
ax.set_xlabel('x',fontsize = 16)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
plt.savefig('2b.svg')

# %%
# c)
fig,ax = plt.subplots(figsize = (8,8))
ax.set_ylim((-2,2))
ax.set_xlim((-2,2))
ax.axhline(0,color = 'k',lw = 0.5)
ax.axvline(0,color = 'k',lw = 0.5)
ax.axhline(0,color = 'k',xmax = 0.5)
ax.axvline(0,color = 'k',ymin = 0.5)
ax.fill_between(x = [-2,0],y1 = 0,y2 = 2,alpha = 0.2)
ax.grid()
ax.set_ylabel('y',fontsize = 16)
ax.set_xlabel('x',fontsize = 16)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.savefig('2c.svg')

# %%
# d)
fig,ax = plt.subplots(figsize = (8,8))
ax.set_ylim((0,8))
ax.set_xlim((0,8))
ax.axvline(2,ls = '--',color = 'k',ymin = 3/8,ymax = 6/8)
ax.axvline(6,color = 'k',ymin = 3/8,ymax = 6/8)
ax.axhline(3,color = 'k',xmin = 2/8,xmax = 6/8)
ax.axhline(6,color = 'k',xmin = 2/8,xmax = 6/8)
ax.fill_between(x = [2,6],y1 = 3,y2 = 6,alpha = 0.2)
ax.grid()
ax.set_ylabel('y',fontsize = 16)
ax.set_xlabel('x',fontsize = 16)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('2d.svg')

# %%
# e)
fig,ax = plt.subplots(figsize = (8,8))
ax.set_ylim((-4,5))
ax.set_xlim((-4,5))
ax.axhline(0,color = 'k',lw = 0.5)
ax.axvline(0,color = 'k',lw = 0.5)
ax.axvline(-2,ls = '--',color = 'k',ymin = 1/9,ymax = 7/9)
ax.axvline(3,color = 'k',ymin = 1/9,ymax = 7/9)
ax.axhline(-3,color = 'k',xmin = 2/9,xmax = 7/9)
ax.axhline(3,color = 'k',xmin = 2/9,xmax = 7/9)
ax.fill_between(x = [-2,3],y1 = -3,y2 = 3,alpha = 0.2)
ax.grid()
ax.set_ylabel('y',fontsize = 16)
ax.set_xlabel('x',fontsize = 16)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.savefig('2e.svg')

# %%
# f)
fig,ax = plt.subplots(figsize = (8,8))
ax.set_ylim((-3,3))
ax.set_xlim((-3,3))
ax.axhline(0,color = 'k',lw = 0.5)
ax.axvline(0,color = 'k',lw = 0.5)
ax.axhline(-1,color = 'k')
ax.axhline(1,color = 'k')
ax.fill_between(x = [-4,5],y1 = -1,y2 = 1,alpha = 0.2)
ax.grid()
ax.set_ylabel('y',fontsize = 16)
ax.set_xlabel('x',fontsize = 16)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.savefig('2f.svg')

# %% [markdown]
# ### Ejercicio 14

# %%
# e)
x = np.array([10,100,200,500,1000,2400])
y = np.array([9.95,9.5,9,7.5,5,-2])

fig,ax = plt.subplots(figsize = (8,8))
ax.plot(x,y,'ko-')
ax.set_ylim((-4,12))
ax.set_xlim((0,2500))
ax.axhline(0,color = 'k',lw = 0.5)
ax.axvline(0,color = 'k',lw = 0.5)
ax.grid()
ax.set_ylabel(r'$y$ [ºC]',fontsize = 16)
ax.set_xlabel(r'$x$ [m.s.n.m.]',fontsize = 16)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig('14.svg')
